# %%
import pandas as pd

# %%
df = pd.read_csv('data/2021.csv')

# %% [markdown]
# # Perguntas a serem respondidas:
#
# Quantos foram os filmes/séries que assisti?
#
# Tipos: filmes, séries, curtas
#
# Qual o mais recente
#
# Qual o mais antigo
#
# Quais os gêneros
#
# Quais os mais votados
#
# Qual o mais longo
#
# Qual o mais curto
#
# A nota média do IMDB
#
# relação votos x média
#
# Quais o diretores
#
# o número de documentários
#
# o número de séries
#
# Filmes assistidos por mês

# %%
# Quantos foram os filmes/séries que assisti?
df.shape
# Out:
# (105, 17)

# %%
df
# Out:
#      Position       Const     Created    Modified  Description  \
# 0           1   tt8878862  2021-03-25  2021-03-25          NaN
# 1           2   tt9140560  2021-03-31  2021-03-31          NaN
# 2           3  tt10167284  2021-04-02  2021-04-02          NaN
# 3           4   tt0814255  2021-04-02  2021-04-02          NaN
# 4           5   tt1854564  2021-04-02  2021-04-02          NaN
# ..        ...         ...         ...         ...          ...
# 100       101   tt2294629  2021-12-26  2021-12-26          NaN
# 101       102  tt11286314  2021-12-29  2021-12-29          NaN
# 102       103   tt7097896  2021-12-31  2021-12-31          NaN
# 103       104  tt12974818  2021-12-31  2021-12-31          NaN
# 104       105  tt10986410  2022-01-01  2022-01-01          NaN
#
#                                                  Title  \
# 0                                     Cidade Invisível
# 1                                          WandaVision
# ...

# %%
# Selecionar as colunas desejadas

# Renomeando as colunas

# %%
df['Title Type'].value_counts()
# Out:
# movie           77
# tvSeries        18
# video            2
# tvMiniSeries     2
# tvSpecial        2
# short            2
# tvEpisode        2
# Name: Title Type, dtype: int64

# %%
df[(df['Title Type'] == 'tvSeries') & (df['Genres'] == 'Comedy')]
# Out:
#     Position       Const     Created    Modified  Description  \
# 80        81   tt1266020  2021-10-29  2021-10-29          NaN
# 82        83   tt0063929  2021-11-01  2021-11-01          NaN
# 83        84   tt0098904  2021-11-01  2021-11-01          NaN
# 88        89  tt10971022  2021-11-13  2021-11-13          NaN
#
#                            Title                                     URL  \
# 80          Parks and Recreation   https://www.imdb.com/title/tt1266020/
# 82  Monty Python's Flying Circus   https://www.imdb.com/title/tt0063929/
# 83                      Seinfeld   https://www.imdb.com/title/tt0098904/
# 88                      The Crew  https://www.imdb.com/title/tt10971022/
#
#    Title Type  IMDb Rating  Runtime (mins)  Year  Genres  Num Votes  \
# 80   tvSeries          8.6            22.0  2009  Comedy     242362
# 82   tvSeries          8.8            30.0  1969  Comedy      72208
# 83   tvSeries          8.8            22.0  1989  Comedy     294248
# ...

# %%
df1 = df[['Position', 'Title', 'Title Type', 'IMDb Rating', 'Year', 'Genres', 'Num Votes', 'Release Date', 'Created', 'Directors']]

# %%
df1 = df1.rename(columns={'Position': 'ID', 'Title': 'Título', 'Title Type': 'Tipo', 'IMDb Rating': 'Nota no IMDB', 'Year': 'Ano', 'Genres': 'Gênero', 'Num Votes': 'Número de Votos', 'Release Date': 'Lançamento', 'Created': 'Adicionado no dia', 'Directors': 'Diretor(a)'})

# %%
df1
# Out:
#       ID                                             Título          Tipo  \
# 0      1                                   Cidade Invisível      tvSeries
# 1      2                                        WandaVision  tvMiniSeries
# 2      3                              Forky Asks a Question      tvSeries
# 3      4  Percy Jackson & the Olympians: The Lightning T...         movie
# 4      5                     Percy Jackson: Sea of Monsters         movie
# ..   ...                                                ...           ...
# 100  101                                             Frozen         movie
# 101  102                                      Don't Look Up         movie
# 102  103                        Venom: Let There Be Carnage         movie
# 103  104                                              David         short
# 104  105                                          Ted Lasso      tvSeries
#
#      Nota no IMDB   Ano                                             Gênero  \
# ...

# %%
# Nota mais alta x Nota mais baixa
df1['Nota no IMDB'].sort_values(ascending=False)
# Out:
# 94     9.1
# 104    8.8
# 40     8.8
# 82     8.8
# 83     8.8
#       ...
# 24     4.4
# 78     4.4
# 96     4.3
# 50     3.8
# 66     3.5
# Name: Nota no IMDB, Length: 105, dtype: float64

# %%
df1.loc[98]
# Out:
# ID                                                   99
# Título                          Spider-Man: No Way Home
# Tipo                                              movie
# Nota no IMDB                                        8.7
# Ano                                                2021
# Gênero               Action, Adventure, Fantasy, Sci-Fi
# Número de Votos                                  457119
# Lançamento                                   2021-12-13
# Adicionado no dia                            2021-12-17
# Diretor(a)                                    Jon Watts
# Name: 98, dtype: object

# %%
# Mais antigo
df1['Lançamento'].sort_values()
# Out:
# 82     1969-10-05
# 95     1979-01-26
# 93     1984-12-03
# 27     1988-06-14
# 83     1989-05-06
#           ...
# 94     2021-11-25
# 99     2021-12-03
# 101    2021-12-05
# 97     2021-12-10
# 98     2021-12-13
# Name: Lançamento, Length: 105, dtype: object

# %%
# Mais recente
df1['Lançamento'].sort_values(ascending=False)
# Out:
# 98     2021-12-13
# 97     2021-12-10
# 101    2021-12-05
# 99     2021-12-03
# 94     2021-11-25
#           ...
# 83     1989-05-06
# 27     1988-06-14
# 93     1984-12-03
# 95     1979-01-26
# 82     1969-10-05
# Name: Lançamento, Length: 105, dtype: object
