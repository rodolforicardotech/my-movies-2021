# %%
import pandas as pd

# %%
df = pd.read_csv('data/2021.csv')

# %% [markdown]
# # Perguntas a serem respondidas:
#
# Quantos foram os filmes/séries que assisti?
#
# Tipos: filmes, séries, curtas
#
# Qual o mais recente
#
# Qual o mais antigo
#
# Quais os gêneros
#
# Quais os mais votados
#
# Qual o mais longo
#
# Qual o mais curto
#
# A nota média do IMDB
#
# relação votos x média
#
# Quais o diretores
#
# o número de documentários
#
# o número de séries
#
# Filmes assistidos por mês

# %%
# Quantos foram os filmes/séries que assisti?
df.shape
# Out:
# (105, 17)

# %%
df['Title Type'].value_counts()
# Out:
# movie           77
# tvSeries        18
# tvSpecial        2
# tvMiniSeries     2
# tvEpisode        2
# video            2
# short            2
# Name: Title Type, dtype: int64

# %%
list(df.columns)
# Out:
# ['Position',
#  'Const',
#  'Created',
#  'Modified',
#  'Description',
#  'Title',
#  'URL',
#  'Title Type',
#  'IMDb Rating',
#  'Runtime (mins)',
#  'Year',
#  'Genres',
#  'Num Votes',
#  'Release Date',
#  'Directors',
#  'Your Rating',
#  'Date Rated']

# %%
df
# Out:
#      Position       Const     Created    Modified  Description  \
# 0           1   tt8878862  2021-03-25  2021-03-25          NaN
# 1           2   tt9140560  2021-03-31  2021-03-31          NaN
# 2           3  tt10167284  2021-04-02  2021-04-02          NaN
# 3           4   tt0814255  2021-04-02  2021-04-02          NaN
# 4           5   tt1854564  2021-04-02  2021-04-02          NaN
# ..        ...         ...         ...         ...          ...
# 100       101   tt2294629  2021-12-26  2021-12-26          NaN
# 101       102  tt11286314  2021-12-29  2021-12-29          NaN
# 102       103   tt7097896  2021-12-31  2021-12-31          NaN
# 103       104  tt12974818  2021-12-31  2021-12-31          NaN
# 104       105  tt10986410  2022-01-01  2022-01-01          NaN
#
#                                                  Title  \
# 0                                     Cidade Invisível
# 1                                          WandaVision
# 2                                Forky Asks a Question
# 3    Percy Jackson & the Olympians: The Lightning T...
# 4                       Percy Jackson: Sea of Monsters
# ..                                                 ...
# 100                                             Frozen
# 101                                      Don't Look Up
# 102                        Venom: Let There Be Carnage
# 103                                              David
# 104                                          Ted Lasso
#
#                                         URL    Title Type  IMDb Rating  \
# 0     https://www.imdb.com/title/tt8878862/      tvSeries          7.3
# 1     https://www.imdb.com/title/tt9140560/  tvMiniSeries          8.0
# 2    https://www.imdb.com/title/tt10167284/      tvSeries          6.8
# 3     https://www.imdb.com/title/tt0814255/         movie          5.9
# 4     https://www.imdb.com/title/tt1854564/         movie          5.8
# ..                                      ...           ...          ...
# 100   https://www.imdb.com/title/tt2294629/         movie          7.4
# 101  https://www.imdb.com/title/tt11286314/         movie          7.2
# 102   https://www.imdb.com/title/tt7097896/         movie          6.0
# 103  https://www.imdb.com/title/tt12974818/         short          7.1
# 104  https://www.imdb.com/title/tt10986410/      tvSeries          8.8
#
#      Runtime (mins)  Year                                             Genres  \
# 0              60.0  2021           Crime, Drama, Fantasy, Mystery, Thriller
# 1             350.0  2021             Action, Comedy, Drama, Fantasy, Sci-Fi
# 2               3.0  2019          Animation, Short, Comedy, Family, Fantasy
# 3             118.0  2010                         Adventure, Family, Fantasy
# 4             106.0  2013                         Adventure, Family, Fantasy
# ..              ...   ...                                                ...
# 100           102.0  2013  Animation, Adventure, Comedy, Family, Fantasy,...
# 101           138.0  2021                              Comedy, Drama, Sci-Fi
# 102            97.0  2021                Action, Adventure, Sci-Fi, Thriller
# 103            11.0  2020                                      Short, Comedy
# 104            30.0  2020                               Comedy, Drama, Sport
#
#      Num Votes Release Date                 Directors  Your Rating  Date Rated
# 0         5223   2021-02-05                       NaN         10.0  2021-03-25
# 1       268626   2021-01-15                       NaN          9.0  2021-04-02
# 2         1932   2019-11-12                       NaN          NaN         NaN
# 3       185094   2010-02-10            Chris Columbus          NaN         NaN
# 4       115844   2013-08-07          Thor Freudenthal          NaN         NaN
# ..         ...          ...                       ...          ...         ...
# 100     604661   2013-11-10  Jennifer Lee, Chris Buck          NaN         NaN
# 101     424787   2021-12-05                Adam McKay          NaN         NaN
# 102     172827   2021-09-14               Andy Serkis          NaN         NaN
# 103        486   2020-09-10                Zach Woods          NaN         NaN
# 104     164752   2020-08-14                       NaN          NaN         NaN
#
# [105 rows x 17 columns]
